# %%
import pandas as pd

# %%
df = pd.read_csv("parsed_bills_115-119_chunks_only_embedded.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121238 entries, 0 to 121237
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   congress           121238 non-null  int64
#  1   measure_type       121238 non-null  object
#  2   measure_number     121238 non-null  int64
#  3   measure_id         121238 non-null  object
#  4   origin_chamber     121238 non-null  object
#  5   current_chamber    121238 non-null  object
#  6   orig_publish_date  121238 non-null  object
#  7   update_date        121238 non-null  object
#  8   title              121238 non-null  object
#  9   action_date        121238 non-null  object
#  10  action_desc        121238 non-null  object
#  11  topic_tags         121238 non-null  object
#  12  text_chunk         121238 non-null  object
#  13  embedding          121238 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 12.9+ MB

# %%
df.head(1)
# Out:
#    congress                 measure_type  measure_number     measure_id  \
# 0       115  House Concurrent Resolution               1  id115hconres1
#
#   origin_chamber current_chamber orig_publish_date update_date  \
# 0          HOUSE           HOUSE        2017-01-03  2017-01-23
#
#                                                title action_date  \
# 0  Regarding consent to assemble outside the seat...  2017-01-03
#
#            action_desc                                         topic_tags  \
# 0  Introduced in House  ['Congress', 'Government Operations and Politi...
#
#                                           text_chunk  \
# 0  Authorizes the Speaker of the House and the Ma...
#
#                                            embedding
# 0  [0.036305759102106094, 0.03212970122694969, 0....

# %%
df['congress'].value_counts()
# Out:
# congress
# 115    33312
# 117    33064
# 116    31081
# 118    21941
# 119     1840
# Name: count, dtype: int64

# %%
grouped_df = df.groupby(['measure_type'])['congress'].value_counts().reset_index()
grouped_df
# Out:
#                     measure_type  congress  count
# 0                     House Bill       115  20873
# 1                     House Bill       117  19537
# 2                     House Bill       116  17814
# 3                     House Bill       118  12897
# 4                     House Bill       119   1214
# 5    House Concurrent Resolution       115    260
# 6    House Concurrent Resolution       117    155
# 7    House Concurrent Resolution       116    141
# 8    House Concurrent Resolution       118    104
# 9    House Concurrent Resolution       119     24
# 10        House Joint Resolution       116    670
# 11        House Joint Resolution       115    228
# 12        House Joint Resolution       118    177
# 13        House Joint Resolution       117    139
# 14        House Joint Resolution       119     65
# 15       House Simple Resolution       117   1761
# 16       House Simple Resolution       115   1560
# 17       House Simple Resolution       116   1459
# ...

# %%
df['origin_chamber'].value_counts()
# Out:
# origin_chamber
# HOUSE     80569
# SENATE    40669
# Name: count, dtype: int64

# %%
df['measure_type'].value_counts()
# Out:
# measure_type
# House Bill                      72335
# Senate Bill                     36305
# House Simple Resolution          6271
# Senate Simple Resolution         3630
# House Joint Resolution           1279
# House Concurrent Resolution       684
# Senate Joint Resolution           419
# Senate Concurrent Resolution      315
# Name: count, dtype: int64
