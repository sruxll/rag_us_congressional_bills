# %%
import pandas as pd
import ast  # To safely evaluate string representations of lists
from collections import OrderedDict # Creates a sorted dictionary (sorted by key)

# %%
df = pd.read_csv("parsed_bills_115-119_chunks_only_embedded.csv", usecols=['topic_tags'])
df
# Out:
#                                                topic_tags
# 0       ['Congress', 'Government Operations and Politi...
# 1       ['Taxation', 'Social Welfare', 'Commemorations...
# 2       ['Congress', 'Economics and Public Finance', '...
# 3       ['Congress', 'Economics and Public Finance', '...
# 4       ['Congress', 'Commemorations', 'Agriculture an...
# ...                                                   ...
# 121233  ['Congress', 'Commemorations', 'Social Science...
# 121234  ['International Affairs', 'Security and Intern...
# 121235  ['International Affairs', 'Security and Intern...
# 121236  ['Education', 'Government Operations and Polit...
# 121237  ['Congress', 'Commemorations', 'Social Science...
#
# [121238 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121238 entries, 0 to 121237
# Data columns (total 1 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   topic_tags  121238 non-null  object
# dtypes: object(1)
# memory usage: 947.3+ KB

# %%
# Convert embeddings from CSV to Lists
df["topic_tags"] = df["topic_tags"].apply(lambda x: list(ast.literal_eval(x)))

# %%
topic_counts = {}
for tags in df['topic_tags']:
    for topic in tags:
        if topic not in topic_counts:
            topic_counts[topic] = 1
        else:
            topic_counts[topic] += 1

# %%
topic_counts
# Out:
# {'Congress': 82736,
#  'Government Operations and Politics': 31005,
#  'Economics and Public Finance': 37010,
#  'House Operations and Politics': 205,
#  'Commemorations': 46776,
#  'Labor and Employment': 24599,
#  'House and Senate': 406,
#  'Senate and Congress': 239,
#  'House and Senate Committees': 1,
#  'House and Senate Affairs': 1,
#  'Taxation': 45823,
#  'Social Welfare': 48729,
#  'Education': 30570,
#  'Health': 46979,
#  'Taxation.': 81,
#  'Social welfare': 5801,
#  'Taxations': 3284,
#  'Finance and Financial Sector': 25900,
#  'Agriculture and Food': 42207,
#  'Transportation and Public Works': 40801,
#  'Commerce': 45055,
#  'Congress and other stakeholders': 7,
#  'Law': 24107,
#  'Agriculture and food': 12015,
#  'Commemoration': 4592,
#  'Congress,': 4955,
#  'Arts, Culture, Religion': 13390,
#  'Houses and Representatives': 26,
#  'Capitol and State Security': 169,
#  'Capitol and State Affairs': 4,
#  'Houses and Minorities': 2,
#  'Senate Minority Congress': 459,
#  'Senate Minority Affairs': 309,
#  'Senate Minority Committee': 124,
#  'House Democrats': 368,
#  'House Affairs': 6,
#  'House': 247,
#  'Housing and Community Development': 4510,
#  'House of Representatives': 460,
#  'House of representatives': 74,
#  'Private Legislation': 12512,
#  'Marines and National Security': 25,
#  'Marines': 11,
#  'Marines and Public Works': 25,
#  'Marines and International Affairs': 2,
#  'Families': 12971,
#  'Capitol and State Capitol': 96,
#  'Capitol and State Building': 101,
#  'Capitol and Congress': 129,
#  'Capitol Hill': 189,
#  'Parliament': 4,
#  'Capitol': 70,
#  'Senate': 284,
#  'International Affairs': 27330,
#  'Social Sciences and History': 25287,
#  'Native Americans': 7389,
#  'Immigration': 20359,
#  'Social Welfare International Affairs': 344,
#  'Science, Technology, Communications': 16180,
#  'NASA Operations and Politics': 34,
#  'NASA Commemorations': 5,
#  "NASA's Education": 1,
#  'Embassy in Jerusalem': 5,
#  'Embassy in Israel': 3,
#  'Embassy International Affairs': 5,
#  'Embassy of Israel': 1,
#  'Jerusalem': 1,
#  'Embassy': 4,
#  'Foreign Trade and International Finance': 7453,
#  'International Affairs and International Affairs': 2745,
#  'International Affairs and International Finance': 2670,
#  'Sports and Recreation': 1269,
#  'International Affairs International Affairs': 1717,
#  'FIFA': 9,
#  'Social sciences and History': 1040,
#  'Capitol and Political Science': 24,
#  'Agriculture, Food, Agriculture': 182,
#  'Agriculture, Food and Food': 17,
#  'Arts, Education, Religion': 576,
#  'Public Lands and Natural Resources': 2478,
#  'Crime and Law Enforcement': 33551,
#  'Emergency Management': 39060,
#  'Crime, Law Enforcement, Religion': 52,
#  'Crime, Law Enforcement, Communications': 115,
#  'House Energy': 107,
#  'Employment and Public Works': 459,
#  'Employment and Law Enforcement': 442,
#  'Employment and Public Health': 402,
#  'Employment and Employment': 269,
#  'Employment and Social Welfare': 173,
#  'Employment and Public Finance': 449,
#  'Capitol, National Security': 90,
#  'Capitol, Politics': 63,
#  'Capitol, Congress': 94,
#  'Environmental Protection': 20080,
#  'Energy': 18607,
#  'Taxation International Affairs': 1541,
#  'Social Sciences, History, Religion': 17,
#  'Civil Rights and Liberties.': 607,
#  'Housing, Community Development': 736,
#  'Private Sector': 58,
#  'Emergency management': 3690,
#  'Air Force and National Security': 347,
#  'Air Transportation and Public Works': 257,
#  'Air Force and International Affairs': 103,
#  'Air Force and International Finance': 66,
#  'Families and Health': 185,
#  'Commemorations:': 80,
#  'Health International': 1400,
#  'China and International Affairs': 296,
#  'Diplomatic Relations': 16,
#  'Diplomatic Affairs': 16,
#  'Diplomatic relations': 12,
#  'China and International Finance': 234,
#  'diplomatic relations': 29,
#  'diplomatic missions': 36,
#  'China and International Development': 84,
#  'Families and Community Development': 184,
#  'Families, National Security': 543,
#  'Families and National Security': 631,
#  'Families, Community Development': 1,
#  'Religion and Law Enforcement': 105,
#  'Religion and Civil Rights': 93,
#  'Religious Freedom': 63,
#  'Religion and Social Sciences': 35,
#  'Religion and Politics': 106,
#  'Religion': 2,
#  'Religion and Public Finance': 105,
#  'Crime, Law Enforcement': 9691,
#  'Crime and law Enforcement': 2697,
#  'Budget and Financial Sector': 487,
#  'Budgetary Control': 462,
#  'Budget and Social Welfare': 268,
#  'Budgetary control': 321,
#  'Budgetary Affairs': 251,
#  'Music and Science': 114,
#  'Music and Public Works': 150,
#  'Music and Communications': 166,
#  'Music and Public Finance': 72,
#  'Environmental Protection International Affairs': 36,
#  'Environmental Protection.': 106,
#  'Environmental protection': 1290,
#  'Transportation and Public works': 5394,
#  'Law 2.': 27,
#  'Social Sciences and Law Enforcement': 1213,
#  'Social Science and History': 2309,
#  'Congress, including Congress': 1,
#  'Healthline': 5,
#  'Emergency Medicine': 1,
#  'Climate Change': 379,
#  'Climate change': 300,
#  'Climate Protection': 228,
#  'Environmental Protection International': 43,
#  'International Affairs, International Affairs': 1114,
#  'NATO and International Affairs': 674,
#  'Security and International Finance': 1474,
#  'Security and International Affairs': 1333,
#  'NATO International Affairs': 329,
#  'Security and Politics': 767,
#  'NATO and NATO': 200,
#  'NATO and International Finance': 429,
#  'Trade and International Finance': 657,
#  'Trade and Financial Sector': 727,
#  'Trade and Foreign Trade': 117,
#  'Trade and Investment': 65,
#  'Social sciences and history': 505,
#  'Health and Public Works': 4039,
#  'Health and Public Health': 2856,
#  'Health and Social Welfare': 846,
#  'Forces and National Security': 1057,
#  'Baseball and Recreation': 69,
#  'Athletics': 199,
#  'Baseball and Basketball': 23,
#  'Baseball and Sports': 31,
#  'baseball': 4,
#  'Embassy Operations and Politics': 5,
#  'Embassy in Egypt': 4,
#  'Animals': 9250,
#  'Medicaid and Medicare': 2979,
#  'Medicaid and Health': 2874,
#  'Medicaid, Health': 2298,
#  'Medicaid Health': 1256,
#  'Medicaid': 2062,
#  'Labor and Employment.': 428,
#  'Congress and other nations': 142,
#  'Congress and other leaders': 156,
#  'Houses and Municipalities': 28,
#  'Commemorations, Letters': 1,
#  'Commemorations and Letters': 15,
#  'Naval Operations and Politics': 23,
#  'Navy Operations and Politics': 2,
#  'Navy and Public Works': 40,
#  'Navy and International Finance': 34,
#  'Navy and International Affairs': 30,
#  'Serbia and International Affairs': 2,
#  'International Affairs and International Education': 269,
#  'China and Taiwan': 67,
#  'China and Russia': 130,
#  'China and Vietnam': 28,
#  'international Affairs': 137,
#  'international affairs': 41,
#  'Government operations and Politics': 1842,
#  'Refugees': 428,
#  'Immigration and Public Works': 530,
#  'Immigration and International Finance': 97,
#  'Immigration International Affairs': 639,
#  'Immigration and International Affairs': 6,
#  'Space and Public Works': 155,
#  'Space and Transportation': 152,
#  'Astronauts': 2,
#  'Space and Public Space': 97,
#  'Sciences and Technology': 106,
#  'Space and Public Transportation': 45,
#  'Space and Public Energy': 10,
#  'Lands and Natural Resources': 169,
#  'Public Land and Natural Resources': 2915,
#  'Social Sciences and Public Finance': 248,
#  'Congress and Congress': 2177,
#  'Congress and Government': 175,
#  'Congress and its': 21,
#  'Congresss': 32,
#  'STEM, Technology, Communications': 89,
#  'Technology and Communications': 1597,
#  'STEM, Science, Communications': 29,
#  'STEM and Science': 220,
#  'Social Justice': 27,
#  'Navy and National Security': 22,
#  'Education and Public Works': 613,
#  'Commemorations.': 204,
#  'Library and Public Works': 26,
#  'Museums and Arts': 31,
#  'Museum and Public Works': 11,
#  'Library and Institutions': 4,
#  'Library and Congress': 27,
#  'Museums and History': 18,
#  'Congress and International Affairs': 740,
#  'Congress.': 1490,
#  'trade and International Finance': 59,
#  'trade and investment': 46,
#  'Social Science and Health': 3,
#  'Social Health': 4017,
#  'Social Sciences and History.': 30,
#  'Haiti': 49,
#  'Haitians': 12,
#  'Export and International Finance': 21,
#  'Exports and Trade': 24,
#  'Export and Public Works': 7,
#  'Export and Trade': 9,
#  'Force and National Security': 293,
#  'Force and Territories': 19,
#  'Government Operations, Politics': 1832,
#  'Armed Forces and National Security': 788,
#  'Armed Forces and National security': 567,
#  'Armed Forces, National Security': 399,
#  'Armed Forces and national Security': 542,
#  'Dogs': 5,
#  'Dogs and cats': 3,
#  'Dogs and Food': 3,
#  'Legislation': 191,
#  'House Politics': 69,
#  'Science, technology, Communications': 5717,
#  'European Affairs': 76,
#  'United Kingdom': 14,
#  'European Union': 50,
#  'European Parliament': 22,
#  'United States': 61,
#  'Climate and Energy': 32,
#  'Climate and Health': 38,
#  'Cancer': 253,
#  'Cancer Health': 25,
#  'Cancer.': 11,
#  'Social Sciences and International Finance': 294,
#  'foreign Trade and International Finance': 18,
#  'foreign trade and International Finance': 12,
#  'Trade and Commerce': 536,
#  'Nations International Affairs': 16,
#  'Infrastructure and Public Works': 129,
#  'Infrastructure and Community Development': 125,
#  'Infrastructure Development': 48,
#  'Infrastructure and Financial Sector': 84,
#  'Infrastructure and Civil Rights': 10,
#  'Capitolations': 25,
#  'Major League Baseball': 2,
#  'baseball player': 2,
#  'baseball and television': 9,
#  'MLB': 11,
#  'Social Labor and Employment': 677,
#  'House Economics and Public Finance': 90,
#  'Arts, Culture and Religion': 657,
#  'Arts, culture, Religion': 57,
#  'Arts, Culture, religion': 2018,
#  'Houses and Recreation': 10,
#  'Armed Force and National Security': 1945,
#  'Families and Governments': 3,
#  'Budgetary and Financial Sector': 5,
#  'Budgetary and Social Welfare': 2,
#  'Housing and Community development': 1278,
#  'Housing and Communities Development': 101,
#  'Housing and Public Works': 426,
#  'Housing and Urban Development': 29,
#  'housing and Community Development': 102,
#  'Income Taxation': 27,
#  'Income and Social Welfare': 12,
#  'Income and Public Finance': 14,
#  'Income and Taxation': 12,
#  'Income and Financial Sector': 6,
#  'Crime and Law Enforcement.': 35,
#  'Crime and Law Enforcement Enforcement': 11,
#  'Elections': 210,
#  'Election': 31,
#  'House Democrats and Republicans': 135,
#  'Health and Families': 1404,
#  'Peace and International Finance': 218,
#  'Peace and Community Development': 147,
#  'Peace and Social Welfare': 21,
#  'Peace and Foreign Trade': 48,
#  'Peace and International Affairs': 119,
#  'Manufacturing': 8,
#  'Manufacturing and Public Works': 33,
#  'Manufacturing and Commerce': 37,
#  'Colleges and Schools': 120,
#  'Colleges and Universities': 121,
#  'Students and Families': 110,
#  'Colleges and universities': 101,
#  'Students': 13,
#  'China and the International Affairs': 18,
#  'China and the United States': 9,
#  'Tibetans': 39,
#  'International Affairs Commemorations': 39,
#  'Bibles': 3,
#  'Religion and Education': 2,
#  'Religion and Culture': 5,
#  'Religion and Public Health': 8,
#  'Religion and Public Law': 50,
#  'STEM Education': 120,
#  'STEM and Technology': 202,
#  'STEM': 209,
#  'House of Congress': 37,
#  'Senate Minority Issues': 212,
#  'Senate Finance and Financial Sector': 167,
#  'Economics and Community Finance': 472,
#  'Economics and Education': 708,
#  'Security and Public Works': 830,
#  'Security': 444,
#  'Senate and National Security': 145,
#  'Security and International Security': 134,
#  'Laborand Employment': 160,
#  'Labor or Employment': 41,
#  'Security and Community Development': 1278,
#  'Economics and History': 665,
#  'Debt': 283,
#  'Debt Issues': 78,
#  'Economics and Social Welfare': 176,
#  'Water Resources Development': 9730,
#  'Natural Resources Development': 88,
#  'Water Resources development': 1168,
#  'Natural Resources Protection': 35,
#  'Natural Resources': 6,
#  'Banking and Financial Sector': 561,
#  'Financial Sector': 921,
#  'Banking and Finance': 544,
#  'Justice': 280,
#  'Crimeand Law Enforcement': 1396,
#  'Health and Community Development': 1006,
#  'Debt Law': 197,
#  'Debt Management': 102,
#  'Debts': 59,
#  'Social Law': 153,
#  'Credit and Financial Sector': 281,
#  'Credit and Social Welfare': 236,
#  'Consumer Protection': 178,
#  'Health and Welfare': 612,
#  'Election Commission': 26,
#  'Defense and National Security': 818,
#  'Defense and Public Works': 810,
#  'Defense and International Finance': 789,
#  'Defense and International Affairs': 716,
#  'Internet Explorer and Firefox': 250,
#  'Computers and Communications': 128,
#  'Computers and Science': 123,
#  'Computers and Technology': 97,
#  'Computer Science and Technology': 24,
#  'Internet Explorer': 136,
#  'Communications': 110,
#  'Senate Minority Law': 6,
#  'Credit and Public Finance': 69,
#  'UN Security and International Affairs': 45,
#  'UN Security and International Finance': 45,
#  'UN Security and International Security': 40,
#  'Government Operations and Politicses': 812,
#  'Health, Families': 1015,
#  'Elections and Public Works': 150,
#  'Elections and National Security': 107,
#  'Elections and Politics': 141,
#  'Elections and Law Enforcement': 12,
#  'Government Operations and Economics': 1362,
#  'Environmental Security': 264,
#  'IRS Taxation': 550,
#  'IRS': 479,
#  'Congress and other members': 11,
#  'Senators': 121,
#  'Representatives': 65,
#  'Senator Paul Ryan': 20,
#  'Senatorry': 20,
#  'Government Operation and Politics': 9,
#  'Environmental Protection and Public Works': 145,
#  'Environmental Protection, National Security': 130,
#  'Environmental Protection, Inc.': 1,
#  'Congress, International Affairs': 198,
#  'Congress, Congress': 10141,
#  'Rights, Liberties, Religion': 3,
#  'Wildlife and Natural Resources': 456,
#  'Wildlife and Environmental Protection': 440,
#  'Wildlife and Public Works': 427,
#  'Water Resource Development': 371,
#  'Crime and Law enforcement': 4118,
#  'Finance and Finance Sector': 252,
#  'Energy and Public Works': 413,
#  'Finance and Finance': 758,
#  'Employment and National Security': 308,
#  'Employment and Politics': 85,
#  'Employment and Community Development': 90,
#  'Animals and Food': 912,
#  'Animals and plants': 886,
#  'Medicare and Medicaid': 2490,
#  'Medicaid Services': 225,
#  'Wildlife Resources Development': 272,
#  'IRS Public Finance': 84,
#  'Gas and Public Works': 118,
#  'Gas and Electricity': 110,
#  'Gas and Electric': 60,
#  'Gas and Fuel': 64,
#  'Education and Public Finance': 37,
#  'Education International Affairs': 126,
#  "Teacher's Education": 20,
#  'Teacher and Student Welfare': 23,
#  'Teacher and Student Rights': 13,
#  'Teacher and Student Health': 2,
#  'Air Resources Development': 104,
#  'Air Pollution': 60,
#  'Air and Water': 19,
#  'Wildlife Management': 122,
#  'Flags and Monuments': 7,
#  'Flags and Means': 7,
#  'Flags and Flags': 6,
#  'Flags': 5,
#  'Flags and International Affairs': 4,
#  'Banking and Public Finance': 402,
#  'Government Operations& Politics': 166,
#  'Security and Foreign Trade': 190,
#  'Foreign Trade and International Development': 40,
#  'Transportation and Law Enforcement': 1072,
#  'Transportation and Community Development': 3256,
#  'Transportation and Government Operations': 964,
#  'Water Resources Development Development': 18,
#  'Water Resources Management': 468,
#  'Transit and Public Works': 153,
#  'Highway and Public Works': 447,
#  'Transport and Public Works': 258,
#  'Highway and Transportation': 416,
#  'Transit and Communications': 107,
#  'Social Science and Technology': 1570,
#  'Clean Environmental Protection': 53,
#  'Clean Water': 64,
#  'Clean Energy': 64,
#  'Clean Water Quality': 6,
#  'Liberties and International Finance': 86,
#  'Liberties and National Security': 84,
#  'Liberties and Fundamental Rights': 30,
#  'Liberties and International Affairs': 60,
#  'Social Sciences and Economics': 1202,
#  'Criminal Law': 475,
#  'Music and Culture': 91,
#  'Music and Literature': 33,
#  'Music and Arts': 24,
#  'Forestry and Public Works': 133,
#  'Forestry and Natural Resources': 132,
#  'Forests and Natural Resources': 109,
#  'Forestry and Environmental Protection': 87,
#  'Forestry and National Security': 86,
#  'Social Taxation': 479,
#  'Taxation Congress': 214,
#  'Financial Sector and Economics': 136,
#  'Transportation and Financial Sector': 515,
#  'Labor and employment': 798,
#  'agency operations and operations': 12,
#  'agency operations and management': 12,
#  'agency operations and policies': 12,
#  'agency control': 6,
#  'agency management': 12,
#  'agencies': 49,
#  'Armed force and National Security': 66,
#  'Private Legitimations': 256,
#  'Armedens and National Security': 25,
#  'Veterans and National Security': 2246,
#  'Veterans Affairs': 2374,
#  'Veterans and Social Welfare': 2011,
#  'Homeland Security': 2630,
#  'Haitian National Security': 8,
#  'Haitian Government': 22,
#  'Haiti International Affairs': 76,
#  'Taxation and Taxation': 17,
#  'Taxation and Public Works': 2,
#  'Medicare': 955,
#  'Finance and Public Sector': 233,
#  'Veterans and Families': 1117,
#  'Food and Drugs': 371,
#  'Food and Agriculture': 1747,
#  'Food and Drink': 1419,
#  'Food and Nutrition': 897,
#  'Food and Drug Administration': 43,
#  'Congress, and': 528,
#  'Crime und Law Enforcement': 376,
#  'Social Welfare Taxation': 129,
#  'Courts and Law Enforcement': 140,
#  'Courts and Public Works': 140,
#  'Attorneys and Public Works': 174,
#  'Courts and National Security': 103,
#  'Courts and Municipality': 33,
#  'Courts and Municipalities': 7,
#  'Agriculture and Food and Food': 443,
#  'Veterans and Congress': 424,
#  'Security and Financial Sector': 158,
#  'Recycling and Public Works': 8,
#  'Recycling and Environmental Protection': 4,
#  'Waste Management': 58,
#  'Recycling and Water Resources': 2,
#  'Families of Immigration': 9,
#  'Public Lands and Natural resources': 281,
#  'Public Lands and Natural Resource': 201,
#  'Medicare and Health': 1049,
#  'Veterans and Community Development': 1066,
#  'Vote': 98,
#  'Voters': 87,
#  'Water resources Development': 226,
#  'Agriculture and Food,': 210,
#  'Agriculture and Foods': 2110,
#  'Trade and Politics': 471,
#  'Trade and Community Development': 78,
#  'Defense and Financial Sector': 468,
#  'Armed Forces andNational Security': 374,
#  'Armed Forceses and National Security': 104,
#  'STEM and Public Finance': 84,
#  'STEM and Public Health': 82,
#  'Law, Law': 43,
#  'Rivers and Natural Resources': 5,
#  'Rivers and Public Works': 5,
#  'River Transportation and Public Works': 1,
#  'River Resources Development': 20,
#  'Agriculture and Agriculture': 16,
#  'Science, Public Finance': 352,
#  'Science, Commerce': 531,
#  'Budget and Financial Perspectives': 6,
#  'Child and Families': 35,
#  'Child and Social Welfare': 37,
#  'Child and Family Welfare': 4,
#  'Employment and Financial Sector': 100,
#  'Native Americans and Native Americans': 1154,
#  'Indians': 408,
#  'Indian Affairs': 218,
#  'Indians and Native Americans': 178,
#  'Immigration International Finance': 179,
#  'Economics, Public Finance': 257,
#  'Economics and Taxation': 30,
#  'Arts, Technology, Communications': 394,
#  'Medicaid Welfare': 144,
#  'Agriculture and Public Finance': 233,
#  'Agriculture and Public Works': 373,
#  'Manufacturing and Technology': 21,
#  'Railroad and Public Works': 120,
#  'Railroad and Transportation': 120,
#  'Railway and Public Works': 8,
#  'Railways and Transportation': 6,
#  'House and Government Operations': 6,
#  'House and Government Affairs': 6,
#  'Taxation International Finance': 377,
#  'Agriculture andFood': 1344,
#  'Congress and Government Operations': 82,
#  'Congress and Governments': 3,
#  'military operations and operations': 17,
#  'Army and National Security': 27,
#  'Army and Civil Rights': 24,
#  'military operations and activities': 17,
#  'Army and Public Works': 17,
#  'Public Land': 137,
#  'Pharmaceutical and Pharmaceutical Sector': 319,
#  'Pharmaceutical and Public Works': 341,
#  'Drug and Law Enforcement': 319,
#  'Drugs and Crime': 329,
#  'Drugs and Cosmetic': 249,
#  'Pharmaceutical and Financial Sector': 206,
#  'Energy, Public Works': 1621,
#  'Energy.': 81,
#  'Crime and Legislation': 2,
#  'Criminal Protection': 342,
#  'Social Welfare,': 117,
#  'Economics and Financial Sector': 305,
#  'Commerce and Public Works': 1315,
#  'Social Education': 259,
#  'Medicare and Supplement': 122,
#  'Homeland Protection': 774,
#  'Food': 54,
#  'Politics and Politics': 52,
#  'Politics and Public Finance': 52,
#  'Politics and Law Enforcement': 47,
#  'FDA': 141,
#  'Agriculture and Food Congress': 2191,
#  'FDA: Environmental Protection': 4,
#  'Science Technology, Communications': 45,
#  'Homeland Security and Public Works': 192,
#  'Homeland Security and National Security': 121,
#  'Transportation and National Security': 196,
#  'Animal Resources Development': 37,
#  'Animal Health': 311,
#  'Families of Health': 22,
#  'IRS Public Works': 120,
#  'Healthcare': 271,
#  'Crime and Politics': 573,
#  'Taxation Issues': 3,
#  'Mortgage and Financial Sector': 149,
#  'Mortgage and Housing Development': 118,
#  'Mortgage and Housing': 115,
#  'Mortgage and Housing Enforcement': 56,
#  'Public Landmarks': 34,
#  'Space and International Finance': 66,
#  'Public Works and Public Works': 20,
#  'Farm and Food': 783,
#  'Farm and Agriculture': 793,
#  'Farm and vegetable': 277,
#  'Farming': 121,
#  'Social Science and Public Finance': 124,
#  'Social Housing and Community Development': 131,
#  'Foreign trade and International Finance': 407,
#  'Foreign Trade and Foreign Finance': 167,
#  'Foreign Trade and Foreign Trade': 477,
#  'Mental Health': 257,
#  'Mental Welfare': 41,
#  'Labor and Welfare': 152,
#  'Emergency Management International': 315,
#  'Business and Public Finance': 477,
#  'Business and Public Works': 470,
#  'Food and Food': 656,
#  'education': 30,
#  'Fish and Animals': 95,
#  'Fish and Food': 108,
#  'Fish and Wildlife': 88,
#  'Fish and Fisheries': 44,
#  'Dances': 8,
#  'Dance and Dance': 7,
#  'Dancers': 6,
#  'Dance and Music': 15,
#  'Health, Public Health': 210,
#  'Employees': 129,
#  'Employee Retirement Income': 68,
#  'Employee Retirement Health': 8,
#  'Employee Retirement Agency': 33,
#  'Social Welfare Welfare': 191,
#  'Commemorations Commemorations': 26,
#  'Government Operations and Politics.': 256,
#  'Emergencymanagement': 79,
#  'Crime/ Law Enforcement': 89,
#  'Emergency Management International Affairs': 490,
#  'Emergency Management International Finance': 94,
#  'Social Welfare and Health': 26,
#  'Social History and History': 4,
#  'Social Sciences and Arts': 31,
#  'Peace and Politics': 61,
#  'Food and Health': 115,
#  'Medicine': 110,
#  'Mortgage and Housing Finance': 88,
#  'Mortgage and Credit Development': 5,
#  'Iraq and Forces': 3,
#  'Iraq and International Affairs': 4,
#  'Iraq and Afghanistan': 8,
#  'Iraq International Affairs': 5,
#  'Iraq and International Finance': 3,
#  'Science, Technology and Communications': 50,
#  'Science and Technology': 35,
#  'Flooding': 133,
#  'Flood Protection': 99,
#  'Flood control': 11,
#  'Finance and Financial sector': 401,
#  'Social Sciences': 69,
#  'Social Affairs': 367,
#  'Agriculture andfood': 1586,
#  'Crime and Public Law Enforcement': 36,
#  'Gas and Financial Sector': 95,
#  'Gas and Electricité': 69,
#  'Air and International Finance': 31,
#  'Air and Space': 200,
#  'Securities and Exchange Commission': 211,
#  'Securities and Exchange Finance': 211,
#  'Securities and Exchanges': 154,
#  'Securities and International Finance': 114,
#  'Securities and Markets': 159,
#  'Financial Perspectives': 288,
#  'Airports and Public Works': 132,
#  'Airport and Public Works': 316,
#  'Airport Transportation and Public Works': 36,
#  'airports and tourist attractions': 2,
#  'airports and tourist destinations': 1,
#  'Airport and City of Houston': 1,
#  'Transportation and Civil Rights': 1280,
#  'Drugs and Alcohol': 164,
#  'Drugs and Food': 99,
#  'Drug and Crime': 226,
#  'Medicaid Law': 26,
#  'Medicaid and Medicaid': 10,
#  'Higher Education': 40,
#  'Medicare and Social Welfare': 159,
#  'Medicare and Medicaid programs': 43,
#  'Medicare and Medicaid Services': 61,
#  'Congress, and Congress': 1796,
#  'Medicare and Medicaid facilities': 5,
#  'Cherokee and Native Americans': 131,
#  'tribes and religion': 154,
#  'Cherokee and Indians': 28,
#  'tribes': 61,
#  'Commerce, Public Works': 330,
#  'Congressd': 177,
#  'Native Americans, National Security': 718,
#  'Native Americans, Native Americans': 262,
#  'Consumerists': 8,
#  'Consumers Protection': 13,
#  'Consumers': 33,
#  'Business and Financial Sector': 426,
#  'Fuels': 42,
#  'Fuel and Energy': 27,
#  'Fuel Development': 41,
#  'Health and Public Finance': 97,
#  'Computers and Operations': 7,
#  'Defence and International Finance': 24,
#  'Defence and Public Works': 10,
#  'Homeland Security and Immigration': 16,
#  'Technology and Public Works': 1353,
#  'Technology and Public Finance': 1181,
#  'taxation': 81,
#  'Science,Tech, Communications': 725,
#  'Finance and Taxation': 473,
#  'Emergency Operations and Politics': 61,
#  'Highways and Transportation': 284,
#  'Highway Resources Development': 15,
#  'Emergency Management.': 192,
#  'Criminal Justice': 162,
#  'Air and Public Works': 101,
#  'Air and Environmental Protection': 24,
#  'Mortgage and Finance': 24,
#  'Labor and Labor': 110,
#  'Congress, Politics': 1066,
#  'Agriculture and Animals': 9,
#  'Native Americans,': 46,
#  'Indian Health': 31,
#  'Student Loans': 48,
#  'Emergency Manager': 55,
#  'Arbitration': 56,
#  'Arbitrations': 43,
#  'Arbitratories': 25,
#  'Arbitrators': 23,
#  'Government Operations and Politics,': 23,
#  'Airport and International Finance': 68,
#  'Airport and State Transportation': 89,
#  'Airport and Community Development': 47,
#  'Airports and Transportation': 90,
#  'Voting': 29,
#  'Votations': 27,
#  'Votation': 4,
#  'Insurance': 125,
#  'Insurance and Public Works': 312,
#  'Animal Families': 51,
#  'Debt Protection': 144,
#  'Fishing and Food': 21,
#  'Financial Affairs': 24,
#  'Alaska and Native Americans': 25,
#  'Alaska and Public Works': 29,
#  'Alaska Congress': 21,
#  'Armed Forces and national security': 87,
#  'Aviation and Public Works': 430,
#  'Airports and International Finance': 17,
#  'Animals and Animals': 92,
#  'Environmental Conservation': 92,
#  'Private Legises': 17,
#  'Crime and Taxation': 488,
#  'Wildlife and Food': 63,
#  'Communications and Public Works': 707,
#  'Communications and International Finance': 346,
#  'Government Operations or Politics': 106,
#  'Energy, Commerce': 298,
#  'Labor and Employment Law': 213,
#  'tribes and National Security': 133,
#  'tribes and Native Americans': 136,
#  'tribes and nationality': 86,
#  'tribes and peoples': 24,
#  'tribes and nationalities': 41,
#  'tribes and national parks': 113,
#  'Homeland Networks': 81,
#  'Airport Operations and Politics': 58,
#  'Airports and National Security': 41,
#  'Welfare': 216,
#  'Homeland Transportation and Public Works': 73,
#  'Native American': 56,
#  'Land and Natural Resources': 37,
#  'Families with disabilities': 80,
#  'Arts, Culture, Religion.': 2,
#  'immigration': 136,
#  'Homeland Security and International Finance': 78,
#  'Transit and National Security': 101,
#  'Transit and Government Operations': 29,
#  'Transit and International Finance': 45,
#  'Home and Community Development': 10,
#  'Homelessness': 8,
#  'Homeless Families': 4,
#  'Homelessness and Reform': 4,
#  'Homeless': 5,
#  'Jurisdiction': 3,
#  'Juris Law': 2,
#  'Jurors': 3,
#  'Jurission': 1,
#  'Jury Law': 1,
#  'Historic Places and Culture': 33,
#  'Historic Resources Development': 60,
#  'Historic Resources and Public Works': 42,
#  'Historic Places and Arts': 7,
#  'Attorneys and National Security': 118,
#  'Attorneys, Public Law': 81,
#  'Attorneys': 176,
#  'Economics and National Finance': 66,
#  'Economics and Public finance': 87,
#  'Banking and Public Works': 189,
#  'Social Sciences and Health': 33,
#  'Electricity': 300,
#  'Electricité': 154,
#  'Electric and Water': 11,
#  'Electric Power': 19,
#  'Refugee and National Security': 3,
#  'Science, Commerce, Communications': 551,
#  'Music': 113,
#  'Health Public Health': 206,
#  'Flood Insurance': 32,
#  'Labor, Employment and Employment': 37,
#  'Labor and Employment and Employment': 185,
#  'Labor, Employment, Religion': 77,
#  'Economics and International Finance': 8,
#  'International affairs': 183,
#  'Global Voices': 334,
#  'Electricity and Energy': 37,
#  'Electricianity': 3,
#  'Finance and International Finance': 55,
#  'Science, Technology, Communication': 69,
#  'Environmental Protection,': 92,
#  'Pensions and Insurance': 29,
#  'Pensions and Health': 4,
#  'Retirement': 96,
#  'Wildlife and Public Health': 195,
#  'Drug and Financial Sector': 111,
#  'Insurance and Financial Sector': 304,
#  'Insurance and Public Finance': 229,
#  'Insurance and Taxation': 160,
#  'Fuels and Oil': 50,
#  'Fuels and Energy': 59,
#  'Culture and Religion': 17,
#  'Culture, Religion': 14,
#  'Culture and Public Health': 10,
#  'Culture and Public Works': 10,
#  'Culture and Identity': 3,
#  'Commerce and Public Finance': 20,
#  'Courts and Government Operations': 58,
#  'IRS Employees': 2,
#  'Agriculture and Food, Food': 185,
#  'Immigration, Public Law': 8,
#  'Immigration and Public Finance': 12,
#  'Security and National Security': 167,
#  'Haitian Education': 4,
#  'Haitian Affairs': 6,
#  'Food and Natural Resources': 134,
#  'Commerce, Commerce': 116,
#  'commerce': 71,
#  'Accounting and Public Finance': 11,
#  'Accounting and Public Works': 11,
#  'Accounting and Financial Sector': 11,
#  'Civil Protection': 19,
#  'Civil Law': 9,
#  'Food and beverage': 69,
#  'Water Quality': 47,
#  'Water Resources Conservation': 68,
#  'Global Health': 134,
#  'Afghanistan and International Affairs': 22,
#  'Afghanistan and International Finance': 20,
#  'Afghanistan and National Security': 11,
#  'Afghanistan and North Korea': 7,
#  'Bankruptcy': 6,
#  'Bank of Commerce': 36,
#  'Bank and Financial Sector': 11,
#  'Bank of America': 17,
#  'Families.': 31,
#  'Business and Politics': 160,
#  'Business and Economics': 118,
#  'IRS taxation': 21,
#  'Natural Resources Management': 11,
#  'Agriculture and Food Agriculture': 99,
#  'Agriculture and Food International': 91,
#  'Social sciences and technology': 37,
#  'House Agriculture and Food': 12,
#  'House, Politics': 68,
#  'Commerce and Commerce': 16,
#  'Commerce International Finance': 53,
#  'Commerces': 18,
#  'Commerce International': 127,
#  'Politics and Government': 14,
#  'Politics': 29,
#  'Wildlife and Nature': 35,
#  'Science, Culture, Religion': 43,
#  'Health Taxation': 45,
#  'Drug and Alcohol': 207,
#  'Drug and Cosmetic': 190,
#  'Disaster Management': 67,
#  'Disaster Relief': 47,
#  'Budget and Market Sector': 6,
#  'Budget and Market Development': 13,
#  'Airport Safety': 2,
#  'Airport Security': 2,
#  'agriculture and food': 81,
#  'animal welfare': 4,
#  'animal rights': 4,
#  'animal cruelty': 4,
#  'animal control': 2,
#  'animals': 4,
#  'Airport and Transportation': 145,
#  'Airport Affairs': 3,
#  'Alaska and Montana': 5,
#  'Alaska and Washington': 5,
#  'Senate and National Assembly': 21,
#  'Native Americans and Indians': 3,
#  'Mining and Finance': 41,
#  'Mining and Construction': 30,
#  'Mining and Transportation': 19,
#  'Mining and Commerce': 4,
#  'Congress, National Security': 95,
#  'Horses and Recreation': 25,
#  'Horses': 23,
#  'Taxation, Law': 133,
#  'Wireless and Public Works': 36,
#  'Wireless and Networks': 50,
#  'Wireless Communications': 35,
#  'Wireless and Communications': 31,
#  'Wireless and Networking': 36,
#  'Wireless and Radio': 12,
#  'Navy and Civil Rights': 10,
#  'Animal Welfare': 42,
#  'Arts, Culture': 64,
#  'Global Affairs': 312,
#  'Labor, Employment and Health': 60,
#  'Medicare and Employment': 66,
#  'Crime and Legality': 79,
#  'Cybersecurity': 50,
#  'Cyber Security': 41,
#  'Cyber Protection': 32,
#  'Social Sciences and Technology': 30,
#  'Internet Explorer and Safari': 71,
#  'Computer and Networks': 43,
#  'Visa and Public Works': 44,
#  'Visas and Immigration': 45,
#  'Visa and Taxation': 13,
#  'Visa and Immigration': 32,
#  'China and India': 154,
#  'China and International affairs': 15,
#  'Electricity and Gas': 14,
#  'Communications and Financial Sector': 40,
#  'Marine Resources Development': 32,
#  'Plants': 9,
#  'Plants and Wildlife': 5,
#  'Plants and Food': 3,
#  'Plants and Agriculture': 3,
#  'Culture, Religion, Religion': 4,
#  'Ambassador to International Affairs': 21,
#  'Ambassador to the United States': 4,
#  'Ambassador to the United Nations': 4,
#  'Ambassador to the International Affairs': 2,
#  'Music and Entertainment': 32,
#  'Music and Television': 5,
#  'Business': 11,
#  'Air pollution': 35,
#  'Child Taxation': 17,
#  'Child Welfare': 254,
#  'Child Development': 335,
#  'Child Protection': 170,
#  'Criminal Law Enforcement': 20,
#  'Families of Fallen': 4,
#  'Congress and other Congress': 93,
#  'Congress and Politics': 105,
#  'Economics and Public Economics': 143,
#  'House and Community Development': 165,
#  'House, Community Development': 52,
#  'Banking and Public Sector': 18,
#  'Congress and Government Finance': 9,
#  'Highway and Emergency Management': 321,
#  'Highway and Community Development': 184,
#  'Schools and Public Works': 198,
#  'Schools and Families': 130,
#  'Schools and Public Schools': 62,
#  'Schools and Recreation': 37,
#  ...}

# %%
sorted_items = sorted(topic_counts.items(), key=lambda kv: (kv[1], kv[0]), reverse=True)
sorted_items
# Out:
# [('Congress', 82736),
#  ('Social Welfare', 48729),
#  ('Health', 46979),
#  ('Commemorations', 46776),
#  ('Taxation', 45823),
#  ('Commerce', 45055),
#  ('Agriculture and Food', 42207),
#  ('Transportation and Public Works', 40801),
#  ('Emergency Management', 39060),
#  ('Economics and Public Finance', 37010),
#  ('Crime and Law Enforcement', 33551),
#  ('Government Operations and Politics', 31005),
#  ('Education', 30570),
#  ('International Affairs', 27330),
#  ('Finance and Financial Sector', 25900),
#  ('Social Sciences and History', 25287),
#  ('Labor and Employment', 24599),
#  ('Law', 24107),
#  ('Immigration', 20359),
#  ('Environmental Protection', 20080),
#  ('Energy', 18607),
#  ('Science, Technology, Communications', 16180),
#  ('Arts, Culture, Religion', 13390),
#  ('Families', 12971),
#  ('Private Legislation', 12512),
#  ('Agriculture and food', 12015),
#  ('Congress, Congress', 10141),
#  ('Water Resources Development', 9730),
#  ('Crime, Law Enforcement', 9691),
#  ('Animals', 9250),
#  ('Foreign Trade and International Finance', 7453),
#  ('Native Americans', 7389),
#  ('Social welfare', 5801),
#  ('Science, technology, Communications', 5717),
#  ('Transportation and Public works', 5394),
#  ('Congress,', 4955),
#  ('Commemoration', 4592),
#  ('Housing and Community Development', 4510),
#  ('Crime and Law enforcement', 4118),
#  ('Health and Public Works', 4039),
#  ('Social Health', 4017),
#  ('Emergency management', 3690),
#  ('Taxations', 3284),
#  ('Transportation and Community Development', 3256),
#  ('Medicaid and Medicare', 2979),
#  ('Public Land and Natural Resources', 2915),
#  ('Medicaid and Health', 2874),
#  ('Health and Public Health', 2856),
#  ('International Affairs and International Affairs', 2745),
#  ('Crime and law Enforcement', 2697),
#  ('International Affairs and International Finance', 2670),
#  ('Homeland Security', 2630),
#  ('Medicare and Medicaid', 2490),
#  ('Public Lands and Natural Resources', 2478),
#  ('Veterans Affairs', 2374),
#  ('Social Science and History', 2309),
#  ('Medicaid, Health', 2298),
#  ('Veterans and National Security', 2246),
#  ('Agriculture and Food Congress', 2191),
#  ('Congress and Congress', 2177),
#  ('Agriculture and Foods', 2110),
#  ('Medicaid', 2062),
#  ('Arts, Culture, religion', 2018),
#  ('Veterans and Social Welfare', 2011),
#  ('Armed Force and National Security', 1945),
#  ('Government operations and Politics', 1842),
#  ('Government Operations, Politics', 1832),
#  ('Congress, and Congress', 1796),
#  ('Food and Agriculture', 1747),
#  ('International Affairs International Affairs', 1717),
#  ('Energy, Public Works', 1621),
#  ('Technology and Communications', 1597),
#  ('Agriculture andfood', 1586),
#  ('Social Science and Technology', 1570),
#  ('Taxation International Affairs', 1541),
#  ('Congress.', 1490),
#  ('Security and International Finance', 1474),
#  ('Food and Drink', 1419),
#  ('Health and Families', 1404),
#  ('Health International', 1400),
#  ('Crimeand Law Enforcement', 1396),
#  ('Government Operations and Economics', 1362),
#  ('Technology and Public Works', 1353),
#  ('Agriculture andFood', 1344),
#  ('Security and International Affairs', 1333),
#  ('Commerce and Public Works', 1315),
#  ('Environmental protection', 1290),
#  ('Transportation and Civil Rights', 1280),
#  ('Security and Community Development', 1278),
#  ('Housing and Community development', 1278),
#  ('Sports and Recreation', 1269),
#  ('Medicaid Health', 1256),
#  ('Social Sciences and Law Enforcement', 1213),
#  ('Social Sciences and Economics', 1202),
#  ('Technology and Public Finance', 1181),
#  ('Water Resources development', 1168),
#  ('Native Americans and Native Americans', 1154),
#  ('Veterans and Families', 1117),
#  ('International Affairs, International Affairs', 1114),
#  ('Transportation and Law Enforcement', 1072),
#  ('Veterans and Community Development', 1066),
#  ('Congress, Politics', 1066),
#  ('Forces and National Security', 1057),
#  ('Medicare and Health', 1049),
#  ('Social sciences and History', 1040),
#  ('Health, Families', 1015),
#  ('Health and Community Development', 1006),
#  ('Transportation and Government Operations', 964),
#  ('Medicare', 955),
#  ('Financial Sector', 921),
#  ('Animals and Food', 912),
#  ('Food and Nutrition', 897),
#  ('Animals and plants', 886),
#  ('Health and Social Welfare', 846),
#  ('Security and Public Works', 830),
#  ('Defense and National Security', 818),
#  ('Government Operations and Politicses', 812),
#  ('Defense and Public Works', 810),
#  ('Economics and Public Finance Congress', 803),
#  ('Labor and employment', 798),
#  ('Farm and Agriculture', 793),
#  ('Defense and International Finance', 789),
#  ('Armed Forces and National Security', 788),
#  ('Technology and Science', 785),
#  ('Farm and Food', 783),
#  ('Homeland Protection', 774),
#  ('Security and Politics', 767),
#  ('Finance and Finance', 758),
#  ('Congress and International Affairs', 740),
#  ('Housing, Community Development', 736),
#  ('Trade and Financial Sector', 727),
#  ('Science,Tech, Communications', 725),
#  ('Native Americans, National Security', 718),
#  ('Defense and International Affairs', 716),
#  ('Economics and Education', 708),
#  ('Communications and Public Works', 707),
#  ('Social Labor and Employment', 677),
#  ('NATO and International Affairs', 674),
#  ('Economics and History', 665),
#  ('Trade and International Finance', 657),
#  ('Arts, Culture and Religion', 657),
#  ('Food and Food', 656),
#  ('Immigration International Affairs', 639),
#  ('Families and National Security', 631),
#  ('Education and Public Works', 613),
#  ('Health and Welfare', 612),
#  ('Civil Rights and Liberties.', 607),
#  ('Arts, Education, Religion', 576),
#  ('Crime and Politics', 573),
#  ('Armed Forces and National security', 567),
#  ('Banking and Financial Sector', 561),
#  ('Science, Commerce, Communications', 551),
#  ('IRS Taxation', 550),
#  ('Banking and Finance', 544),
#  ('Families, National Security', 543),
#  ('Armed Forces and national Security', 542),
#  ('Trade and Commerce', 536),
#  ('Science, Commerce', 531),
#  ('Immigration and Public Works', 530),
#  ('Congress, and', 528),
#  ('Transportation and Financial Sector', 515),
#  ('Social sciences and history', 505),
#  ('Emergency Management International Affairs', 490),
#  ('Crime and Taxation', 488),
#  ('Budget and Financial Sector', 487),
#  ('Social Taxation', 479),
#  ('IRS', 479),
#  ('Foreign Trade and Foreign Trade', 477),
#  ('Business and Public Finance', 477),
#  ('Criminal Law', 475),
#  ('Finance and Taxation', 473),
#  ('Economics and Community Finance', 472),
#  ('Trade and Politics', 471),
#  ('Business and Public Works', 470),
#  ('Water Resources Management', 468),
#  ('Defense and Financial Sector', 468),
#  ('Budgetary Control', 462),
#  ('House of Representatives', 460),
#  ('Senate Minority Congress', 459),
#  ('Employment and Public Works', 459),
#  ('Wildlife and Natural Resources', 456),
#  ('Employment and Public Finance', 449),
#  ('Highway and Public Works', 447),
#  ('Security', 444),
#  ('Agriculture and Food and Food', 443),
#  ('Employment and Law Enforcement', 442),
#  ('Wildlife and Environmental Protection', 440),
#  ('Aviation and Public Works', 430),
#  ('NATO and International Finance', 429),
#  ('Refugees', 428),
#  ('Labor and Employment.', 428),
#  ('Wildlife and Public Works', 427),
#  ('Housing and Public Works', 426),
#  ('Business and Financial Sector', 426),
#  ('Veterans and Congress', 424),
#  ('Highway and Transportation', 416),
#  ('Energy and Public Works', 413),
#  ('Indians', 408),
#  ('Foreign trade and International Finance', 407),
#  ('House and Senate', 406),
#  ('Employment and Public Health', 402),
#  ('Banking and Public Finance', 402),
#  ('Finance and Financial sector', 401),
#  ('Armed Forces, National Security', 399),
#  ('Arts, Technology, Communications', 394),
#  ('Climate Change', 379),
#  ('bill', 377),
#  ('Taxation International Finance', 377),
#  ('Crime und Law Enforcement', 376),
#  ('Armed Forces andNational Security', 374),
#  ('Agriculture and Public Works', 373),
#  ('Water Resource Development', 371),
#  ('Food and Drugs', 371),
#  ('House Democrats', 368),
#  ('Social Affairs', 367),
#  ('Science, Public Finance', 352),
#  ('Air Force and National Security', 347),
#  ('Communications and International Finance', 346),
#  ('Social Welfare International Affairs', 344),
#  ('Criminal Protection', 342),
#  ('Pharmaceutical and Public Works', 341),
#  ('Child Development', 335),
#  ('Global Voices', 334),
#  ('Commerce, Public Works', 330),
#  ('NATO International Affairs', 329),
#  ('Drugs and Crime', 329),
#  ('Highway and Emergency Management', 321),
#  ('Budgetary control', 321),
#  ('Pharmaceutical and Pharmaceutical Sector', 319),
#  ('Drug and Law Enforcement', 319),
#  ('Airport and Public Works', 316),
#  ('Emergency Management International', 315),
#  ('Insurance and Public Works', 312),
#  ('Global Affairs', 312),
#  ('Animal Health', 311),
#  ('Senate Minority Affairs', 309),
#  ('Employment and National Security', 308),
#  ('Economics and Financial Sector', 305),
#  ('Insurance and Financial Sector', 304),
#  ('Electricity', 300),
#  ('Climate change', 300),
#  ('Energy, Commerce', 298),
#  ('China and International Affairs', 296),
#  ('Social Sciences and International Finance', 294),
#  ('Force and National Security', 293),
#  ('Financial Perspectives', 288),
#  ('Senate', 284),
#  ('Highways and Transportation', 284),
#  ('Debt', 283),
#  ('Public Lands and Natural resources', 281),
#  ('Credit and Financial Sector', 281),
#  ('Justice', 280),
#  ('Farm and vegetable', 277),
#  ('Wildlife Resources Development', 272),
#  ('Healthcare', 271),
#  ('International Affairs and International Education', 269),
#  ('Employment and Employment', 269),
#  ('Budget and Social Welfare', 268),
#  ('Environmental Security', 264),
#  ('Native Americans, Native Americans', 262),
#  ('Social Education', 259),
#  ('Transport and Public Works', 258),
#  ('Mental Health', 257),
#  ('Economics, Public Finance', 257),
#  ('Air Transportation and Public Works', 257),
#  ('Private Legitimations', 256),
#  ('Government Operations and Politics.', 256),
#  ('Child Welfare', 254),
#  ('Cancer', 253),
#  ('Finance and Finance Sector', 252),
#  ('Budgetary Affairs', 251),
#  ('Internet Explorer and Firefox', 250),
#  ('Drugs and Cosmetic', 249),
#  ('Social Sciences and Public Finance', 248),
#  ('House', 247),
#  ('Pharmaceutical and Pharmaceutical Development', 246),
#  ('Senate and Congress', 239),
#  ('Islamic Law', 238),
#  ('Credit and Social Welfare', 236),
#  ('China and International Finance', 234),
#  ('Finance and Public Sector', 233),
#  ('Agriculture and Public Finance', 233),
#  ('Insurance and Public Finance', 229),
#  ('Climate Protection', 228),
#  ('Energy Congress', 227),
#  ('Water resources Development', 226),
#  ('Drug and Crime', 226),
#  ('School and Public Works', 225),
#  ('Native Americans, National Geographic', 225),
#  ('Medicaid Services', 225),
#  ('Cancer and Cancer', 224),
#  ('STEM and Science', 220),
#  ('Peace and International Finance', 218),
#  ('Indian Affairs', 218),
#  ('Welfare', 216),
#  ('Taxation Congress', 214),
#  ('Labor and Employment Law', 213),
#  ('Senate Minority Issues', 212),
#  ('Securities and Exchange Finance', 211),
#  ('Securities and Exchange Commission', 211),
#  ('Health, Public Health', 210),
#  ('Elections', 210),
#  ('Agriculture and Food,', 210),
#  ('STEM', 209),
#  ('Islamic Republics', 208),
#  ('Farm and Natural Resources', 208),
#  ('Drug and Alcohol', 207),
#  ('Pharmaceutical and Financial Sector', 206),
#  ('Health Public Health', 206),
#  ('School and Community Development', 205),
#  ('House Operations and Politics', 205),
#  ('Aviation and Civil Rights', 205),
#  ('Commemorations.', 204),
#  ('STEM and Technology', 202),
#  ('Cancer and Health', 202),
#  ('Public Lands and Natural Resource', 201),
#  ('Islamic Republic', 201),
#  ('NATO and NATO', 200),
#  ('Air and Space', 200),
#  ('Athletics', 199),
#  ('Schools and Public Works', 198),
#  ('Congress, International Affairs', 198),
#  ('Debt Law', 197),
#  ('Transportation and National Security', 196),
#  ('Air Force and International Security', 196),
#  ('Wildlife and Public Health', 195),
#  ('Homeland Security and Public Works', 192),
#  ('Emergency Management.', 192),
#  ('Air and Transportation', 192),
#  ('Social Welfare Welfare', 191),
#  ('Legislation', 191),
#  ('Security and Foreign Trade', 190),
#  ('Drug and Cosmetic', 190),
#  ('Capitol Hill', 189),
#  ('Banking and Public Works', 189),
#  ('Social Welfare Congress', 185),
#  ('Labor and Employment and Employment', 185),
#  ('Families and Health', 185),
#  ('Agriculture and Food, Food', 185),
#  ('Highway and Community Development', 184),
#  ('Families and Community Development', 184),
#  ('International affairs', 183),
#  ('Farm and vegetable production', 183),
#  ('Agriculture, Food, Agriculture', 182),
#  ('Islamic Republic of China', 181),
#  ('Agriculture and Public Resources', 180),
#  ('Immigration International Finance', 179),
#  ('Indians and Native Americans', 178),
#  ('Consumer Protection', 178),
#  ('Congressd', 177),
#  ('Economics and Social Welfare', 176),
#  ('Attorneys', 176),
#  ('Congress and Government', 175),
#  ('Attorneys and Public Works', 174),
#  ('Homeland Development', 173),
#  ('Employment and Social Welfare', 173),
#  ('Child Protection', 170),
#  ('Lands and Natural Resources', 169),
#  ('Capitol and State Security', 169),
#  ('Senate Finance and Financial Sector', 167),
#  ('Security and National Security', 167),
#  ('Foreign Trade and Foreign Finance', 167),
#  ('Music and Communications', 166),
#  ('Government Operations& Politics', 166),
#  ('House and Community Development', 165),
#  ('NATO and International Security', 164),
#  ('Drugs and Alcohol', 164),
#  ('Public Landations', 162),
#  ('Criminal Justice', 162),
#  ('Solar Energy', 161),
#  ('Farm and Animals', 161),
#  ('Laborand Employment', 160),
#  ('Insurance and Taxation', 160),
#  ('Business and Politics', 160),
#  ('Securities and Markets', 159),
#  ('Medicare and Social Welfare', 159),
#  ('Security and Financial Sector', 158),
#  ('Food and Wine', 157),
#  ('Congress and other leaders', 156),
#  ('Space and Public Works', 155),
#  ('tribes and religion', 154),
#  ('Securities and Exchanges', 154),
#  ('Electricité', 154),
#  ('China and India', 154),
#  ('Violence and Law Enforcement', 153),
#  ('Transit and Public Works', 153),
#  ('Social Law', 153),
#  ('Athletics and Sports', 153),
#  ('Space and Transportation', 152),
#  ('Labor and Welfare', 152),
#  ('Music and Public Works', 150),
#  ('Elections and Public Works', 150),
#  ('Mortgage and Financial Sector', 149),
#  ('Peace and Community Development', 147),
#  ('Animals and Natural Resources', 147),
#  ('Pharmaceutical and Food', 146),
#  ('Senate and National Security', 145),
#  ('Environmental Protection and Public Works', 145),
#  ('Airport and Transportation', 145),
#  ('Veterans Protection', 144),
#  ('Medicaid Welfare', 144),
#  ('Debt Protection', 144),
#  ('livestock and poultry', 143),
#  ('Economics and Public Economics', 143),
#  ('Medicare and Congress', 142),
#  ('Congress and other nations', 142),
#  ('FDA', 141),
#  ('Elections and Politics', 141),
#  ('Aviation and Community Development', 141),
#  ('Courts and Public Works', 140),
#  ('Courts and Law Enforcement', 140),
#  ('Agriculture and Health', 138),
#  ('livestock and food', 137),
#  ('international Affairs', 137),
#  ('Public Land', 137),
#  ('tribes and Native Americans', 136),
#  ('immigration', 136),
#  ('Internet Explorer', 136),
#  ('Financial Sector and Economics', 136),
#  ('House Democrats and Republicans', 135),
#  ('Child Health', 135),
#  ('Security and International Security', 134),
#  ('Indigenous Americans', 134),
#  ('Global Health', 134),
#  ('Food and Natural Resources', 134),
#  ('tribes and National Security', 133),
#  ('Taxation, Law', 133),
#  ('Forestry and Public Works', 133),
#  ('Flooding', 133),
#  ('Forestry and Natural Resources', 132),
#  ('Airports and Public Works', 132),
#  ('Social Housing and Community Development', 131),
#  ('Cherokee and Native Americans', 131),
#  ('Schools and Families', 130),
#  ('Families and Government', 130),
#  ('Environmental Protection, National Security', 130),
#  ('China and Russia', 130),
#  ('Social Welfare Taxation', 129),
#  ('Infrastructure and Public Works', 129),
#  ('Employees', 129),
#  ('Capitol and Congress', 129),
#  ('Homeland security', 128),
#  ('Computers and Communications', 128),
#  ('Technology and Broadcast', 127),
#  ('Commerce International', 127),
#  ('Education International Affairs', 126),
#  ('Technology, Communications', 125),
#  ('Insurance', 125),
#  ('Infrastructure and Community Development', 125),
#  ('Social Science and Public Finance', 124),
#  ('Senate Minority Committee', 124),
#  ('Computers and Science', 123),
#  ('Wildlife Management', 122),
#  ('Medicare and Supplement', 122),
#  ('Islamic Fundamentalism', 122),
#  ('Trade and Law Enforcement', 121),
#  ('Senators', 121),
#  ('Islamic State', 121),
#  ('Homeland Security and National Security', 121),
#  ('Farming', 121),
#  ('Colleges and Universities', 121),
#  ('STEM Education', 120),
#  ('Railroad and Transportation', 120),
#  ('Railroad and Public Works', 120),
#  ('IRS Public Works', 120),
#  ('Colleges and Schools', 120),
#  ('Peace and International Affairs', 119),
#  ('Mortgage and Housing Development', 118),
#  ('Gas and Public Works', 118),
#  ('Farms and Agriculture', 118),
#  ('Business and Economics', 118),
#  ('Attorneys and National Security', 118),
#  ('Trade and Foreign Trade', 117),
#  ('Social Welfare,', 117),
#  ('School and Education', 117),
#  ('International Affairs and Public Works', 117),
#  ('Supreme Court Judges', 116),
#  ('Nursing and Health', 116),
#  ('Commerce, Commerce', 116),
#  ('Mortgage and Housing', 115),
#  ('Food and Health', 115),
#  ('Crime, Law Enforcement, Communications', 115),
#  ('Credit and Social Finance', 115),
#  ('Cancer and Food', 115),
#  ('Securities and International Finance', 114),
#  ('Music and Science', 114),
#  ('Medicare and Community Development', 114),
#  ('House and Representatives', 114),
#  ('tribes and national parks', 113),
#  ('Music', 113),
#  ('Supreme Court', 111),
#  ('Drug and Financial Sector', 111),
#  ('Students and Families', 110),
#  ('Medicine', 110),
#  ('Labor and Labor', 110),
#  ('Gas and Electricity', 110),
#  ('Communications', 110),
#  ('Forests and Natural Resources', 109),
#  ('Fish and Food', 108),
#  ('Transit and Communications', 107),
#  ('House Energy', 107),
#  ('Elections and National Security', 107),
#  ('Sciences and Technology', 106),
#  ('Religion and Politics', 106),
#  ('Government Operations or Politics', 106),
#  ('Environmental Protection.', 106),
#  ('Religion and Public Finance', 105),
#  ('Religion and Law Enforcement', 105),
#  ('Congress and Politics', 105),
#  ('Violence and Civil Rights', 104),
#  ('Refugee Families', 104),
#  ('Internet Explorer and Communications', 104),
#  ('Armed Forceses and National Security', 104),
#  ('Air Resources Development', 104),
#  ('Courts and National Security', 103),
#  ('Air Force and International Affairs', 103),
#  ('housing and Community Development', 102),
#  ('National Security', 102),
#  ('Debt Management', 102),
#  ('Transport and Financial Sector', 101),
#  ('Transit and National Security', 101),
#  ('Pharmaceuticals', 101),
#  ('Money and Public Finance', 101),
#  ('Housing and Communities Development', 101),
#  ('Education International', 101),
#  ('Colleges and universities', 101),
#  ('Capitol and State Building', 101),
#  ('Air and Public Works', 101),
#  ('Public Land, Natural Resources', 100),
#  ('Employment and Financial Sector', 100),
#  ('Aerospace and Public Works', 100),
#  ('Money and Social Welfare', 99),
#  ('Flood Protection', 99),
#  ('Drugs and Food', 99),
#  ('Aviation and Financial Sector', 99),
#  ('Athletics and Recreation', 99),
#  ('Agriculture and Food Agriculture', 99),
#  ('Vote', 98),
#  ('Recreation and Public Works', 98),
#  ('Supreme Law', 97),
#  ('Space and Public Space', 97),
#  ('Internet and Public Works', 97),
#  ('Immigration and International Finance', 97),
#  ('Health and Public Finance', 97),
#  ('Health International Affairs', 97),
#  ('Computers and Technology', 97),
#  ('Senate Agriculture and Food', 96),
#  ('Retirement', 96),
#  ('Capitol and State Capitol', 96),
#  ('tribes and people', 95),
#  ('Gas and Financial Sector', 95),
#  ('Fish and Animals', 95),
#  ('Congress, National Security', 95),
#  ('Armed Forces and International Affairs', 95),
#  ('housing and community development', 94),
#  ('Emergency Management International Finance', 94),
#  ('Capitol, Congress', 94),
#  ('Religion and Civil Rights', 93),
#  ('Nuclear Energy', 93),
#  ('Internet and Communications', 93),
#  ('Congress and other Congress', 93),
#  ('Environmental Protection,', 92),
#  ('Environmental Conservation', 92),
#  ('Animals and Animals', 92),
#  ('Music and Culture', 91),
#  ('Energy Development', 91),
#  ('Agriculture and Food International', 91),
#  ('Urban Development', 90),
#  ('House Economics and Public Finance', 90),
#  ('Employment and Community Development', 90),
#  ('Capitol, National Security', 90),
#  ('Airports and Transportation', 90),
#  ('STEM, Technology, Communications', 89),
#  ('IRS: Taxation', 89),
#  ('Crime/ Law Enforcement', 89),
#  ('Airport and State Transportation', 89),
#  ('Technology and Public Sector', 88),
#  ('Natural Resources Development', 88),
#  ('Mortgage and Housing Finance', 88),
#  ('Fish and Wildlife', 88),
#  ('Energy International Finance', 88),
#  ('Defense and International Security', 88),
#  ('Voters', 87),
#  ('School and Families', 87),
#  ('Forestry and Environmental Protection', 87),
#  ('Educational Development', 87),
#  ('Economics and Public finance', 87),
#  ('Arts, Sciences, Religion', 87),
#  ('Armed Forces and national security', 87),
#  ('tribes and nationality', 86),
#  ('UN International Affairs', 86),
#  ('Sports and Public Works', 86),
#  ('Liberties and International Finance', 86),
#  ('Forestry and National Security', 86),
#  ('Families and Government Operations', 86),
#  ('Sexuality', 85),
#  ('Employment and Politics', 85),
#  ('Colleges and Arts', 85),
#  ('STEM and Public Finance', 84),
#  ('Pharmaceutical and Pharmaceutical', 84),
#  ('Liberties and National Security', 84),
#  ('Infrastructure and Financial Sector', 84),
#  ('IRS Public Finance', 84),
#  ('Hong Kong International Affairs', 84),
#  ('China and International Development', 84),
#  ('Agriculture and Natural Resources', 84),
#  ('Supreme Court Judge', 83),
#  ('Highways and Recreation', 83),
#  ('budgetary control', 82),
#  ('Vehicles and Transportation', 82),
#  ('Social and Political Sciences', 82),
#  ('STEM and Public Health', 82),
#  ('Public Lands and Natural Sciences', 82),
#  ('Money and Finance', 82),
#  ('Congress and Government Operations', 82),
#  ('taxation', 81),
#  ('agriculture and food', 81),
#  ('Taxation.', 81),
#  ('Homeland Networks', 81),
#  ('Energy.', 81),
#  ('Criminal Defense', 81),
#  ('Attorneys, Public Law', 81),
#  ('Agriculture and Public Food', 81),
#  ('livestock and livestock', 80),
#  ('Families with disabilities', 80),
#  ('Commemorations:', 80),
#  ('Agriculture and Public Health', 80),
#  ('budgetary advisors', 79),
#  ('Refugee Protection', 79),
#  ('Emergencymanagement', 79),
#  ('Crime and Legality', 79),
#  ('Trade and Community Development', 78),
#  ('Homeland Security and International Finance', 78),
#  ('Educational Opportunities', 78),
#  ('Debt Issues', 78),
#  ('Labor, Employment, Religion', 77),
#  ('Congress or Congress', 77),
#  ('Capitol Arts and Culture', 77),
#  ('livestock and meat', 76),
#  ('Haiti International Affairs', 76),
#  ('European Affairs', 76),
#  ('Islamic Fundamentalists', 75),
#  ('House of representatives', 74),
#  ('Censusation', 74),
#  ('Africa and International Finance', 74),
#  ('School Education', 73),
#  ('Railroad and Civil Rights', 73),
#  ('Homeland Transportation and Public Works', 73),
#  ('Ships and Transportation', 72),
#  ('Patent and Law Enforcement', 72),
#  ('NATO Operations and Politics', 72),
#  ('Music and Public Finance', 72),
#  ('Employment and Public Sector', 72),
#  ('commerce', 71),
#  ('Islamic Republic of Iran', 71),
#  ('Internet Explorer and Safari', 71),
#  ('Cuba International Affairs', 71),
#  ('Aviation and Law Enforcement', 71),
#  ('livestock and plants', 70),
#  ('Farm and vegetable products', 70),
#  ('Capitol', 70),
#  ('Africa and Middle East', 70),
#  ('tribal rights and rights', 69),
#  ('Trade and Public Works', 69),
#  ('Social Sciences', 69),
#  ('Science, Technology, Communication', 69),
#  ('House Politics', 69),
#  ('Gas and Electricité', 69),
#  ('Food and beverage', 69),
#  ('Farm and vegetable farming', 69),
#  ('Credit and Public Finance', 69),
#  ('Court of Law Enforcement', 69),
#  ('College and University Affairs', 69),
#  ('Baseball and Recreation', 69),
#  ('Water Resources Conservation', 68),
#  ('House, Politics', 68),
#  ('Employee Retirement Income', 68),
#  ('Airport and International Finance', 68),
#  ('United Nations', 67),
#  ('Prison and State Security', 67),
#  ('Olympic and International Affairs', 67),
#  ('Disaster Management', 67),
#  ('China and Taiwan', 67),
#  ('Census and Public Works', 67),
#  ('Space and International Finance', 66),
#  ('Medicare and Employment', 66),
#  ('Finance and Public Finance', 66),
#  ('Economics and National Finance', 66),
#  ('China International Affairs', 66),
#  ('Armed force and National Security', 66),
#  ('Air Force and International Finance', 66),
#  ('Trade and Investment', 65),
#  ('Representatives', 65),
#  ('Olympic and International Finance', 65),
#  ('LGBT rights', 65),
#  ('firearms and ammunition', 64),
#  ('Violence and Public Health', 64),
#  ('Veterans and Forces', 64),
#  ('Insurance and Finance', 64),
#  ('Gas and Fuel', 64),
#  ('Credit and Finance', 64),
#  ('Clean Water', 64),
#  ('Clean Energy', 64),
#  ('Arts, Culture', 64),
#  ('Arts and Culture', 64),
#  ('Africa and International Affairs', 64),
#  ('Africa and Asia', 64),
#  ('Wildlife and Food', 63),
#  ('Religious Freedom', 63),
#  ('Capitol, Politics', 63),
#  ('Aeronautical and Public Works', 63),
#  ('Aeronautical Systems', 63),
#  ('Space and Energy', 62),
#  ('Social Sciences and history', 62),
#  ('Schools and Public Schools', 62),
#  ('Iran', 62),
#  ('Internet Science and Technology', 62),
#  ('Cancer Prevention', 62),
#  ('tribes and natural Resources', 61),
#  ('tribes', 61),
#  ('United States', 61),
#  ('Peace and Politics', 61),
#  ('Music and Public Arts', 61),
#  ('Medicare and Medicaid Services', 61),
#  ('Haiti and Haiti', 61),
#  ('Emergency Operations and Politics', 61),
#  ('Educational Technology and Communications', 61),
#  ('Consumer Affairs', 61),
#  ('Communications and Community Development', 61),
#  ('Students and Teachers', 60),
#  ('Social and Social Sciences', 60),
#  ('Senate and House', 60),
#  ('Science, Transportation, Communications', 60),
#  ('National Park and Recreation', 60),
#  ('Music and History', 60),
#  ('Liberties and International Affairs', 60),
#  ('Labor, Employment and Health', 60),
#  ('Historic Resources Development', 60),
#  ('Gas and Electric', 60),
#  ('Families, Health', 60),
#  ('Educational Resources', 60),
#  ('Air Pollution', 60),
#  ('Agriculture and Food.', 60),
#  ('trade and International Finance', 59),
#  ('Fuels and Energy', 59),
#  ('Debts', 59),
#  ('Waste Management', 58),
#  ('Private Sector', 58),
#  ('Nuclear and Solar Energy', 58),
#  ('Money and Public Works', 58),
#  ('Courts and Government Operations', 58),
#  ('Athletics and Sport', 58),
#  ('Airport Operations and Politics', 58),
#  ('Space and Public Finance', 57),
#  ('Nursing and Employment', 57),
#  ('Iran and International Affairs', 57),
#  ('Infrastructure and Public Finance', 57),
#  ('Financial and Financial Sector', 57),
#  ('Attorneys and Law Enforcement', 57),
#  ('Arts, culture, Religion', 57),
#  ('Olympic and International Sports', 56),
#  ('Native American', 56),
#  ('Mortgage and Housing Enforcement', 56),
#  ('Housing and Development', 56),
#  ('Haiti and International Affairs', 56),
#  ('Consumer Product Safety', 56),
#  ('Arbitration', 56),
#  ('Trade and Finance', 55),
#  ('Sexual orientation', 55),
#  ('Railroad Operations and Transportation', 55),
#  ('Finance and International Finance', 55),
#  ('Emergency Manager', 55),
#  ('Nursing and Food', 54),
#  ('Food', 54),
#  ('Cuban Congress', 54),
#  ('Cuba', 54),
#  ('School and Sports', 53),
#  ('LGBT Issues', 53),
#  ('Internet Explorer and Science', 53),
#  ('Indigenous peoples', 53),
#  ('Energy Management', 53),
#  ('Cuban President', 53),
#  ('Consumer Product Protection', 53),
#  ('Commerce International Finance', 53),
#  ('Clean Environmental Protection', 53),
#  ('China and Foreign Trade', 53),
#  ('Census and Politics', 53),
#  ('Solar Power', 52),
#  ('Politics and Public Finance', 52),
#  ('Politics and Politics', 52),
#  ('House, Community Development', 52),
#  ('Crime, Law Enforcement, Religion', 52),
#  ('Teachers and Students', 51),
#  ('Students and Public Works', 51),
#  ('Space and Technology', 51),
#  ('Security International Affairs', 51),
#  ('Recreation and Sports', 51),
#  ('NASA', 51),
#  ('Congress passes', 51),
#  ('Animal Families', 51),
#  ('tribes and territories', 50),
#  ('Wireless and Networks', 50),
#  ('Science, Technology and Communications', 50),
#  ('Religion and Public Law', 50),
#  ('Fuels and Oil', 50),
#  ('European Union', 50),
#  ('Cybersecurity', 50),
#  ('agencies', 49),
#  ('Social Sciences and Finance', 49),
#  ('Schools and Schools', 49),
#  ('House, Representative', 49),
#  ('Haiti', 49),
#  ('Fire and Emergency Management', 49),
#  ('Communications and Public Finance', 49),
#  ('Vehicle and Public Works', 48),
#  ('Student Loans', 48),
#  ('Social Sciences and Law', 48),
#  ('Retirement Income Taxation', 48),
#  ('Recreation and Natural Resources', 48),
#  ('Peace and Foreign Trade', 48),
#  ('Nuclear and Energy', 48),
#  ('Infrastructure Development', 48),
#  ('Fire and Environmental Protection', 48),
#  ('Agricultural and Food', 48),
#  ('firearms and firearms', 47),
#  ('Water Quality', 47),
#  ('Retirement and Financial Sector', 47),
#  ('Politics and Law Enforcement', 47),
#  ('Money and Financial Sector', 47),
#  ('Mining and Public Works', 47),
#  ('HIV/AIDS', 47),
#  ('Farm and Social Welfare', 47),
#  ('Economics and Public Health', 47),
#  ('Disaster Relief', 47),
#  ('Debt and Economics', 47),
#  ('Airport and Community Development', 47),
#  ('African Americans', 47),
#  ('trade and investment', 46),
#  ('Veterans Administration', 46),
#  ('Transportation, Public Works', 46),
#  ('Teachers and Schools', 46),
#  ('Native Americans,', 46),
#  ('Hong Kong Congress', 46),
#  ('Farms and Food', 46),
#  ('Families:', 46),
#  ('Capitol Building', 46),
#  ('tribes and Government Operations', 45),
#  ('Visas and Immigration', 45),
#  ('UN Security and International Finance', 45),
#  ('UN Security and International Affairs', 45),
#  ('Transit and International Finance', 45),
#  ('Trade and Economics', 45),
#  ('Students and Politics', 45),
#  ('Space and Public Transportation', 45),
#  ('Senate and House Finance', 45),
#  ('Science Technology, Communications', 45),
#  ('Health Taxation', 45),
#  ('Haiti, International Affairs', 45),
#  ('Commemorations,', 45),
#  ('Visa and Public Works', 44),
#  ('Senate Affairs', 44),
#  ('Parks and Recreation', 44),
#  ('Football and Recreation', 44),
#  ('Fish and Fisheries', 44),
#  ('Farming and Food', 44),
#  ('FDA Response', 44),
#  ('Water Resources Protection', 43),
#  ('Social Sciences and Civil Rights', 43),
#  ('Senate Operations and Politics', 43),
#  ('Science, Culture, Religion', 43),
#  ('Medicare and Medicaid programs', 43),
#  ('Law, Law', 43),
#  ('Food and Drug Administration', 43),
#  ('Environmental Protection International', 43),
#  ('Computer and Networks', 43),
#  ('Basketball andrestries', 43),
#  ('Arbitrations', 43),
#  ('Solar and Solar', 42),
#  ('Sciences, Technology, Communications', 42),
#  ('Retirement and Public Finance', 42),
#  ('Renewable Energy', 42),
#  ('Nurses', 42),
#  ('Nuclear and Public Works', 42),
#  ('Internet Explorer and Android', 42),
#  ('Historic Resources and Public Works', 42),
#  ('Fuels', 42),
#  ('Foreign Trade and International finance', 42),
#  ('Congress Congress', 42),
#  ('Business and Public Sector', 42),
#  ('Basketball and Sports', 42),
#  ('Animal Welfare', 42),
#  ('Air Traffic and Transportation', 42),
#  ('tribes and nationalities', 41),
#  ('international affairs', 41),
#  ('firearms', 41),
#  ('Ships and Public Works', 41),
#  ('Sexuality and Health', 41),
#  ('Mining and Finance', 41),
#  ('Mental Welfare', 41),
#  ('Labor or Employment', 41),
#  ('Islamic Republic of Turkey', 41),
#  ('Fuel Development', 41),
#  ('Fire and Natural Resources', 41),
#  ('Defense', 41),
#  ('Cyber Security', 41),
#  ('Cuba and International Affairs', 41),
#  ('Catholicism', 41),
#  ('Airports and National Security', 41),
#  ('tribes and tribes', 40),
#  ('Waste management', 40),
#  ('UN Security and International Security', 40),
#  ('Treasury and Financial Sector', 40),
#  ('Social Sciences or History', 40),
#  ('Social Arts and History', 40),
#  ('Navy and Public Works', 40),
#  ('Native Hawaiians', 40),
#  ('Islamic Affairs', 40),
#  ('Higher Education', 40),
#  ('Foreign Trade and International Development', 40),
#  ('Educational and Public Works', 40),
#  ('Communications and Financial Sector', 40),
#  ('Basketball andrestry', 40),
#  ('Aviation and Transportation', 40),
#  ('firearms and other materials', 39),
#  ('Veterans and Civil Rights', 39),
#  ('Vehicle and Transportation', 39),
#  ('Transportation and Environmental Protection', 39),
#  ('Tibetans', 39),
#  ('School Districts', 39),
#  ('Monuments and Public Works', 39),
#  ('Monuments and Natural Resources', 39),
#  ('Monuments and Monuments', 39),
#  ('International Affairs Commemorations', 39),
#  ('Highway and Environmental Protection', 39),
#  ('Haiti and International Finance', 39),
#  ('Gymnastics and Sports', 39),
#  ('Debate', 39),
#  ('Basketball and Public Works', 39),
#  ('Africa and Latin America', 39),
#  ('Treasury and Public Works', 38),
#  ('Treasury and Public Finance', 38),
#  ('Treasury and National Security', 38),
#  ('Social Welfare International', 38),
#  ('Sciences and Public Finance', 38),
#  ('Prison and Public Works', 38),
#  ('Olympic and National Security', 38),
#  ('Mental Health International', 38),
#  ('Medicines', 38),
#  ('Internet Resources Development', 38),
#  ('Gymnastics and Fitness', 38),
#  ('Congress and National Security', 38),
#  ('Climate and Health', 38),
#  ('Solar PV', 37),
#  ('Social sciences and technology', 37),
#  ('Schools and Recreation', 37),
#  ('Manufacturing and Commerce', 37),
#  ('Land and Natural Resources', 37),
#  ('Labor, Employment and Employment', 37),
#  ('House of Congress', 37),
#  ('Fuels and Fuel', 37),
#  ('Foreign Trade and National Security', 37),
#  ('Electricity and Energy', 37),
#  ('Education and Public Finance', 37),
#  ('Child and Social Welfare', 37),
#  ('Census', 37),
#  ('Animal Resources Development', 37),
#  ('diplomatic missions', 36),
#  ('Wireless and Public Works', 36),
#  ('Wireless and Networking', 36),
#  ('Transit and Sports', 36),
#  ('Ship and Transportation', 36),
#  ('Science/Tech', 36),
#  ('Nursing and Care', 36),
#  ('National Park and Wildlife', 36),
#  ('NATO', 36),
#  ('Farming and Agriculture', 36),
#  ('Environmental Protection International Affairs', 36),
#  ('Educational and Public Finance', 36),
#  ('Crime and Public Law Enforcement', 36),
#  ('Bank of Commerce', 36),
#  ('Airport Transportation and Public Works', 36),
#  ('finance and Financial Sector', 35),
#  ('Wireless Communications', 35),
#  ('Wildlife and Nature', 35),
#  ('Supreme Court Judgement', 35),
#  ('Science and Technology', 35),
#  ('STEM and Public Education', 35),
#  ('Religion and Social Sciences', 35),
#  ('Nuclear and International Finance', 35),
#  ('Natural Resources Protection', 35),
#  ('Cuba and International Finance', 35),
#  ('Criminal Procedure', 35),
#  ('Crime and Law Enforcement.', 35),
#  ('Child and Families', 35),
#  ('Child Abduction', 35),
#  ('Air pollution', 35),
#  ('housing and community Development', 34),
#  ('Water Resources Development International', 34),
#  ('Taxation International', 34),
#  ('Social Finance and Financial Sector', 34),
#  ...]

# %%
len(sorted_items)
# Out:
# 5374

# %%
df1 = pd.DataFrame.from_dict(sorted_items)
df1
# Out:
#                                 0      1
# 0                        Congress  82736
# 1                  Social Welfare  48729
# 2                          Health  46979
# 3                  Commemorations  46776
# 4                        Taxation  45823
# ...                           ...    ...
# 5369  Africa and Pacific Conflict      1
# 5370            Africa and Oceans      1
# 5371                  Afghanistan      1
# 5372                  Aeronautica      1
# 5373        International Affairs      1
#
# [5374 rows x 2 columns]
